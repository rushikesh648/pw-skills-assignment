# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikesh648/pw-skills-assignment/blob/main/stat_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# q1 Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.
import scipy.stats as stats
import numpy as np
sample = [1,2,3,5,6,8]
sample_mean = np.mean(sample)
sample_std = np.std(sample)
sample_size = len(sample)
population_mean = 2
alpha = 0.05
z_score = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
p_value = stats.norm.sf(abs(z_score))
print("Z-score:", z_score)
print("P-value:", p_value)
if p_value < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Z-score: 2.2026517294271297
# P-value: 0.013809652458845457
# Reject null hypothesis

# %%
# q2  Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
import scipy.stats as stats
import numpy as np
np.random.seed(0)
sample = np.random.normal(loc=0, scale=1, size=100)
t_statistic, p_value = stats.ttest_1samp(sample, popmean=0)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# P-value: 0.5562489158694675
# Fail to reject the null hypothesis

# %%
# q3  Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
import scipy.stats as stats
import numpy as np
sample = [1,2,3,5,6,8]
sample_mean = np.mean(sample)
sample_std = np.std(sample)
sample_size = len(sample)
population_mean = 2
alpha = 0.05
z_score = (sample_mean - population_mean) / (sample_std / np.sqrt(sample_size))
p_value = stats.norm.sf(abs(z_score))
print("Z-score:", z_score)
print("P-value:", p_value)
if p_value < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Z-score: 2.2026517294271297
# P-value: 0.013809652458845457
# Reject null hypothesis

# %%
# q4  Perform a two-tailed Z-test using Python and visualize the decision region on a plot.
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
sample = np.random.normal(loc=0, scale=1, size=100)
sample_mean = np.mean(sample)
sample_std = np.std(sample)
sample_size = len(sample)
population_mean = 0
population_std = 1
population_size = 100
alpha = 0.05
z_scores = np.linspace(-4, 4, 100)
p_values = stats.norm.sf(np.abs(z_scores))
plt.plot(z_scores, p_values)
plt.axhline(y=alpha/2, color='r', linestyle='--')
plt.axhline(y=1-alpha/2, color='r', linestyle='--')
plt.xlabel("Z-score")
plt.ylabel("P-value")
plt.title("Two-tailed Z-test")
plt.show()

# %%
# q5 Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
def plot_errors(alpha, beta):
    x = np.linspace(0, 1, 100)
    y1 = stats.beta.pdf(x, 1-alpha, beta)
    y2 = stats.beta.pdf(x, alpha, 1-beta)
    plt.plot(x, y1, label="Type 1 error")
    plt.plot(x, y2, label="Type 2 error")
    plt.xlabel("Probability")
    plt.ylabel("Density")
    plt.legend()
    plt.show
    return
plot_errors(0.05, 0.2)
plot_errors(0.01, 0.2)
plot_errors(0.05, 0.02)
plot_errors(0.01, 0.02)
plot_errors(0.05, 0.1)
plot_errors(0.01, 0.1)
plot_errors(0.05, 0.05)
plot_errors(0.01, 0.05)

# %%
# q6  Write a Python program to perform an independent T-test and interpret the results.
import scipy.stats as stats
import numpy as np
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
t_statistic, p_value = stats.ttest_ind(sample1, sample2)
print("T-statistic:", t_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# T-statistic: -0.2523772325625342
# P-value: 0.8058611078909526
# Fail to reject null hypothesis

# %%
# q7 Perform a paired sample T-test using Python and visualize the comparison results.
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
t_statistic, p_value = stats.ttest_rel(sample1, sample2)
print("T-statistic:", t_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# T-statistic: -1.0
# P-value: 0.36321746764912255
# Fail to reject null hypothesis

# %%
# q8  Simulate data and perform both Z-test and T-test, then compare the results using Python.
import scipy.stats as stats
import numpy as np
np.random.seed(0)
sample1 = np.random.normal(loc=0, scale=1, size=100)
sample2 = np.random.normal(loc=0, scale=1, size=100)
t_statistic, p_value = stats.ttest_ind(sample1, sample2)
print("T-statistic:", t_statistic)
print("P-value:", p_value)
z_score = (np.mean(sample1) - np.mean(sample2)) / np.sqrt(np.var(sample1)/len(sample1) + np.var(sample2)/len(sample2))
p_value = stats.norm.sf(abs(z_score))
print("Z-score:", z_score)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# T-statistic: -0.15295815048595532
# P-value: 0.8785870431170582
# Z-score: -0.15372872539049431
# P-value: 0.4389118172079779
# Fail to reject null hypothesis

# %%
# q9 Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
import scipy.stats as stats
import numpy as np
sample = [1,2,3,5,6,8]
sample_mean = np.mean(sample)
sample_std = np.std(sample)
sample_size = len(sample)
confidence_level = 0.95
t_critical = stats.t.ppf((1 + confidence_level) / 2, df=sample_size - 1)
margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)
print("Confidence interval:", confidence_interval)
# Out:
# Confidence interval: (1.638080824972771, 6.6952525083605625)

# %%
# q10  Write a Python program to calculate the margin of error for a given confidence level using sample data.
import scipy.stats as stats
import numpy as np
sample = [1,2,3,5,6,8]
sample_mean = np.mean(sample)
sample_std = np.std(sample)
sample_size = len(sample)
confidence_level = 0.95
t_critical = stats.t.ppf((1 + confidence_level) / 2, df=sample_size - 1)
margin_of_error = t_critical * (sample_std / np.sqrt(sample_size))
print("Margin of error:", margin_of_error)
# Out:
# Margin of error: 2.528585841693896

# %%
# q11  Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
import scipy.stats as stats
import numpy as np
def bayes_theorem(prior_prob, likelihood, evidence):
    posterior_prob = (prior_prob * likelihood) / evidence
    return posterior_prob

prior_prob = 0.5
likelihood = 0.7
evidence = 0.8
posterior_prob = bayes_theorem(prior_prob, likelihood, evidence)
print("Posterior probability:", posterior_prob)
# Out:
# Posterior probability: 0.43749999999999994

# %%
# q12  Perform a Chi-square test for independence between two categorical variables in Python.
import scipy.stats as stats
import numpy as np
observed = np.array([[10, 20, 30], [6, 9, 17]])
chi2, p, dof, expected = stats.chi2_contingency(observed)
alpha = 0.05
if p < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
print("Chi-square statistic:", chi2)
print("P-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:", expected)
# Out:
# Fail to reject null hypothesis
# Chi-square statistic: 0.27157465150403504
# P-value: 0.873028283380073
# Degrees of freedom: 2
# Expected frequencies: [[10.43478261 18.91304348 30.65217391]
#  [ 5.56521739 10.08695652 16.34782609]]

# %%
# q13 Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.
import scipy.stats as stats
import numpy as np
observed = np.array([[10, 20, 30], [6, 9, 17]])
chi2, p, dof, expected = stats.chi2_contingency(observed)
print("Expected frequencies:", expected)
# Out:
# Expected frequencies: [[10.43478261 18.91304348 30.65217391]
#  [ 5.56521739 10.08695652 16.34782609]]

# %%
# q14  Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
import scipy.stats as stats
import numpy as np
observed = np.array([10, 20, 30, 40])
expected = np.array([0.25, 0.25, 0.25, 0.25])
print("Chi-squared statistic:", chi2)
print("p-value:", p)
if p < 0.05:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# Chi-squared statistic: 0.27157465150403504
# p-value: 0.873028283380073
# Fail to reject the null hypothesis

# %%
# q15  Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.
import scipy.stats as chi2
import numpy as np
import matplotlib.pyplot as plt
df = 10
x = np.linspace(0, 30, 100)
y = chi2.chi2.pdf(x, df)
plt.plot(x, y)
plt.xlabel("Chi-square statistic")
plt.ylabel("Probability density")
plt.title("Chi-square distribution")
plt.show()

# %%
# q16  Implement an F-test using Python to compare the variances of two random samples.
import scipy.stats as stats
import numpy as np
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
f_statistic, p_value = stats.f_oneway(sample1, sample2)
print("F-statistic:", f_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# F-statistic: 0.06369426751592358
# P-value: 0.8058611078909518
# Fail to reject null hypothesis

# %%
# q17 Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.
import scipy.stats as f_oneway
import numpy as np
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
f_statistic, p_value = f_oneway.f_oneway(sample1, sample2)
print("F-statistic:", f_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# F-statistic: 0.06369426751592358
# P-value: 0.8058611078909518
# Fail to reject null hypothesis

# %%
# q18  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.
import scipy.stats as f_oneway
import numpy as np
import matplotlib.pyplot as plt
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
f_statistic, p_value = f_oneway.f_oneway(sample1, sample2)
print("F-statistic:", f_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")

data = [sample1, sample2]
plt.boxplot(data)
plt.show()
# Out:
# F-statistic: 0.06369426751592358
# P-value: 0.8058611078909518
# Fail to reject null hypothesis

# %%
# q19 Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA
import scipy.stats as stats
import numpy as np
def check_assumptions(data):
    normal = stats.shapiro
    independent = stats.levene
    equal_variance = stats.bartlett
    return normal, independent, equal_variance
    return
data = [1,2,3,5,6,8]
check_assumptions(data)
# Out:
# (<function scipy.stats._morestats.shapiro(x, *, axis=None, nan_policy='propagate', keepdims=False)>,
#  <function scipy.stats._morestats.levene(*samples, center='median', proportiontocut=0.05, axis=0, nan_policy='propagate', keepdims=False)>,
#  <function scipy.stats._morestats.bartlett(*samples, axis=0, nan_policy='propagate', keepdims=False)>)

# %%
# q20  Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot
data = pd.DataFrame({
    'factor1': [1, 1, 1, 2, 2, 2, 3, 3, 3],
    'factor2': [1, 2, 3, 1, 2, 3, 1, 2, 3],
    'response': [1, 2, 3, 4, 5, 6, 7, 8, 9]
})
model = ols('response ~ factor1 + factor2 + factor1:factor2', data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
sns.boxplot(x='factor1', y='response', data=data)
sns.boxplot(x='factor2', y='response', data=data)
sns.stripplot(x='factor1', y='response', data=data, jitter=True)
sns.stripplot(x='factor2', y='response', data=data, jitter=True)
sns.scatterplot(x='factor1', y='factor2', data=data)
plt.show()
# Out:
#                        sum_sq   df             F        PR(>F)
# factor1          5.400000e+01  1.0  9.707943e+29  2.044023e-74
# factor2          6.000000e+00  1.0  1.078660e+29  4.966976e-72
# factor1:factor2  9.321501e-30  1.0  1.675789e-01  6.992190e-01
# Residual         2.781228e-28  5.0           NaN           NaN

# %%
# q21  Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.
import scipy.stats as f
import numpy as np
import matplotlib.pyplot as plt
df1 = 10
df2 = 20
x = np.linspace(0, 5, 100)
y = f.f.pdf(x, df1, df2)
plt.plot(x, y)
plt.xlabel("F-statistic")
plt.ylabel("Probability density")
plt.title("F-distribution")
plt.show()

# %%
# q22  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.
import scipy.stats as f_oneway
import numpy as np
import matplotlib.pyplot as plt
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
f_statistic, p_value = f_oneway.f_oneway(sample1, sample2)
print("F-statistic:", f_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
    data = [sample1, sample2]
    plt.boxplot(data)
    plt.show()
# Out:
# F-statistic: 0.06369426751592358
# P-value: 0.8058611078909518
# Fail to reject null hypothesis

# %%
# q23 Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.
import scipy.stats as stats
import numpy as np
np.random.seed(0)
sample = np.random.normal(loc=0, scale=1, size=100)
sample_mean = np.mean(sample)
sample_std = np.std(sample)
sample_size = len(sample)
population_mean = 0
population_std = 1
population_size = 100
alpha = 0.05
t_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(population_size))
p_value = stats.norm.sf(abs(t_statistic))
print("T-statistic:", t_statistic)
print("P-value:", p_value)
if p_value < alpha:
    print("Reject null hypothesis")
    print("The means are significantly different")
else:
    print("Fail to reject null hypothesis")
    print("The means are not significantly different")
# Out:
# T-statistic: 0.5980801553448499
# P-value: 0.2748932254312084
# Fail to reject null hypothesis
# The means are not significantly different

# %%
# q24  Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.
import scipy.stats as chi2
import numpy as np
sample = [1,2,3,5,6,8]
sample_mean = np.mean(sample)
sample_std = np.std(sample)
sample_size = len(sample)
population_mean = 2
population_std = 1
population_size = 100
alpha = 0.05
chi2_statistic = ((sample_size - 1) * sample_std**2) / population_std**2
sample_variance = np.var(sample, ddof=1)
population_variance = population_std**2
chi2_critical_lower = chi2.chi2.ppf(alpha/2, sample_size-1)
chi2_critical_upper = chi2.chi2.ppf(1-alpha/2, sample_size-1)
print("Chi-square statistic:", chi2_statistic)
print("Chi-square critical value:", chi2_critical_lower, chi2_critical_upper)
if chi2_statistic > chi2_critical_lower and chi2_statistic < chi2_critical_upper:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Chi-square statistic: 29.02777777777778
# Chi-square critical value: 0.8312116134866625 12.832501994030027
# Fail to reject null hypothesis

# %%
# q25  Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.
import numpy as np
import statsmodels.api as sm
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
prop_sample1 = len(sample1) / (len(sample1) + len(sample2))
prop_sample2 = len(sample2) / (len(sample1) + len(sample2))
z_statistic, p_value = sm.stats.proportions_ztest([len(sample1), len(sample2)], [len(sample1) + len(sample2), len(sample1) + len(sample2)])
pooled_proportion = (len(sample1) + len(sample2)) / (len(sample1) * len(sample2))
print("Z-statistic:", z_statistic)
print("P-value:", p_value)
alpha = 0.05
if p_value < alpha:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Z-statistic: 0.0
# P-value: 1.0
# Fail to reject null hypothesis

# %%
# q26 Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.
import numpy as np
import scipy.stats as f
import matplotlib.pyplot as plt
sample1 = [1,2,3,5,6,8]
sample2 = [2,3,4,5,6,7]
f_statistic, p_value = f.f_oneway(sample1, sample2)
print("F-statistic:", f_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
    x = np.linspace(0, 10, 100)
    y = f.f.pdf(x, len(sample1)-1, len(sample2)-1)
    plt.plot(x, y)
    plt.xlabel("F-statistic")
    plt.ylabel("Probability density")
    plt.title("F-distribution")
    plt.show()
# Out:
# F-statistic: 0.06369426751592358
# P-value: 0.8058611078909518
# Fail to reject null hypothesis

# %%
# q27  Perform a Chi-square test for goodness of fit with simulated data and analyze the results.
import numpy as np
import scipy.stats as chi2
observed = np.array([10, 20, 30, 40])
total = np.sum(observed)
expected = np.array([0.25, 0.25, 0.25, 0.25]) * total
chi2_statistic, p_value = chi2.chisquare(f_obs=observed, f_exp=expected)
df = len(observed) - 1
p_value = 1 - chi2.chi2.cdf(chi2_statistic, df)
print("Chi-square statistic:", chi2_statistic)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject null hypothesis")
else:
    print("Fail to reject null hypothesis")
# Out:
# Chi-square statistic: 20.0
# P-value: 0.00016974243555278878
# Reject null hypothesis

# %% [markdown]
# Q1 What is hypothesis testing in statistics?
#
# ans: Hypothesis testing can be defined as a statistical tool that is used to identify if the results of an experiment are meaningful or not.
#
# Q2  What is the null hypothesis, and how does it differ from the alternative hypothesis.
#
# ans: A null hypothesis is a statement, in which there is no relationship between two variables. An alternative hypothesis is a statement; that is simply the inverse of the null hypothesis, i.e. there is some statistical significance between two measured phenomenon.
#
# Q3  What is the significance level in hypothesis testing, and why is it important.
#
# ans: Significance levels, often denoted by the Greek letter α (alpha), represent the probability of rejecting a true null hypothesis in a statistical test. In simpler terms, they indicate the maximum acceptable risk of concluding that an effect exists when it actually doesn't.
#
# Q4  What does a P-value represent in hypothesis testing.
#
# ans: The p-value, or probability value, is a statistical measure used in hypothesis testing to assess the strength of evidence against a null hypothesis. It represents the probability of obtaining results as extreme as, or more extreme than, the observed results under the assumption that the null hypothesis is true.
#
# Q5  How do you interpret the P-value in hypothesis testing.
#
# ans: The p value tells you how often you would expect to see a test statistic as extreme or more extreme than the one calculated by your statistical test if the null hypothesis of that test was true. The p value gets smaller as the test statistic calculated from your data gets further away from the range of test statistics predicted by the null hypothesis.
#
# Q6 What are Type 1 and Type 2 errors in hypothesis testing.
#
# ans: Type I and Type II Errors are central for hypothesis testing in general, which subsequently impacts various aspects of science including but not limited to statistical analysis. False discovery refers to a Type I error where a true Null Hypothesis is incorrectly rejected. On the other end of the spectrum, Type II errors occur when a true null hypothesis fails to get rejected.
#
# Q7 What is the difference between a one-tailed and a two-tailed test in hypothesis testing.
#
# ans: One and Two-Tailed Tests are ways to identify the relationship between the statistical variables. For checking the relationship between variables in a single direction (Left or Right direction), we use a one-tailed test. A two-tailed test is used to check whether the relations between variables are in any direction or not.
#
# Q8 What is the Z-test, and when is it used in hypothesis testing.
#
# ans: A z-test is a statistical test to determine whether two population means are different or to compare one mean to a hypothesized value when the variances are known and the sample size is large. A z-test is a hypothesis test for data that follows a normal distribution.
#
# Q9 How do you calculate the Z-score, and what does it represent in hypothesis testing.
#
# ans: The resulting Z-score represents the number of standard deviations that the sample mean deviates from the population mean. This Z-Score is also known as Z-Statistics, and can be formulated as: ext {Z-Score} = frac {bar {x}-mu} {sigma} Z-Score = σxˉ−μ where, bar {x} xˉ : mean of the sample.
#
# Q10 What is the T-distribution, and when should it be used instead of the normal distribution.
#
# ans: The t-distribution should be used instead of the normal distribution in situations where the sample size is small (typically n < 30) and when the population standard deviation is unknown.
#
# Q11 What is the difference between a Z-test and a T-test.
#
# ans: Z-test is used when the standard deviation is available and the sample is large, while the T-test is used when the standard deviation or the variance is unknown.
#
# Q12  What is the T-test, and how is it used in hypothesis testing.
#
# ans: t-tests are commonly used in inferential statistics for testing a hypothesis on the basis of a difference between sample means.
#
# Q13 What is the relationship between Z-test and T-test in hypothesis testing.
#
# ans: The t-test is used when the population variance is unknown, or the sample size is small (n < 30). At the same time, the z-test is applied when the population variance (σ2) is known and the sample size is large (n > 30).
#
# Q14 What is a confidence interval, and how is it used to interpret statistical results.
#
# ans: In statistical analysis, a confidence interval is a range of values that is likely to contain the true population parameter with a certain level of confidence. It is an important tool for interpreting data and making inferences about the population based on a sample.
#
# Q15 What is the margin of error, and how does it affect the confidence interval.
#
# ans: The margin of error is a statistic expressing the amount of random sampling error in the results of a survey. The larger the margin of error, the less confidence one should have that a poll result would reflect the result of a census of the entire population. The margin of error will be positive whenever a population is incompletely sampled and the outcome measure has positive variance, which is to say, whenever the measure varies.
#
# Q16 How is Bayes' Theorem used in statistics, and what is its significance.
#
# ans: Bayes’ Theorem is used to determine the conditional probability of an event. It is used to find the probability of an event, based on prior knowledge of conditions that might be related to that event.
#
# Q17 What is the Chi-square distribution, and when is it used.
#
# ans: Chi-square (Χ 2) distributions are a family of continuous probability distributions. They’re widely used in hypothesis tests, including the chi-square goodness of fit test and the chi-square test of independence.
#
# Q18  What is the Chi-square goodness of fit test, and how is it applied.
#
# ans: A chi-square (Χ2) goodness of fit test is a goodness of fit test for a categorical variable. Goodness of fit is a measure of how well a statistical model fits a set of observations.
#
# > When goodness of fit is high, the values expected based on the model are close to the observed values.
#
# > When goodness of fit is low, the values expected based on the model are far from the observed values.
#
# Q19 What is the F-distribution, and when is it used in hypothesis testing.
#
# ans: The F distribution is a probability distribution used in statistical hypothesis testing to compare the variances of two populations. It is formed by the ratio of two chi-squared distributions and is commonly used in analysis of variance (ANOVA) and regression analysis.
#
# Q20 What is an ANOVA test, and what are its assumptions.
#
# ans: ANOVA tests the hypothesis that the means of two or more populations are equal, generalizing the t-test to more than two groups. It’s commonly used in experiments where various factors’ effects are compared. It can also handle complex experiments with factors that have different numbers of levels.
#
# Q21 What are the different types of ANOVA tests.
#
# ans: There are two main types: one-way and two-way. Two-way tests can be with or without replication.
#
# >One-way ANOVA between groups: used when you want to test two groups to see if there’s a difference between them.
#
# >Two way ANOVA without replication: used when you have one group and you’re double-testing that same group.
#
# For example, you’re testing one set of individuals before and after they take a medication to see if it works or not.
#
# >Two way ANOVA with replication: Two groups, and the members of those groups are doing more than one thing.
#
#  For example, two groups of patients from different hospitals trying two different therapies.
#
#  Q22  What is the F-test, and how does it relate to hypothesis testing?
#
# ans: F test is a statistical test that is used in hypothesis testing that determines whether the variances of two samples are equal or not. The article will provide detailed information on f test, f statistic, its calculation, critical value and how to use it to test hypotheses. To understand F test firstly we need to have some basic understanding of F-distribution.
